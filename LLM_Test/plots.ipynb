# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../Code#1/Bard/BertScore.csv',sep=",",index_col=0)
df2 = pd.read_csv('../Code#1/ChatGPT_3.5/BertScore.csv',sep=",",index_col=0)
df3 = pd.read_csv('../Code#1/ChatGPT_4/BertScore.csv',sep=",",index_col=0)
df4 = pd.read_csv('../Code#1/CodeLlama/BertScore.csv',sep=",",index_col=0)
df5 = pd.read_csv('../Code#1/Platypus2/BertScore.csv',sep=",",index_col=0)
df6 = pd.read_csv('../Code#1/StableCode/BertScore.csv',sep=",",index_col=0)

daf1 = pd.read_csv('../Code#2/Bard/BertScore.csv',sep=",",index_col=0)
daf2 = pd.read_csv('../Code#2/ChatGPT_3.5/BertScore.csv',sep=",",index_col=0)
daf3 = pd.read_csv('../Code#2/ChatGPT_4/BertScore.csv',sep=",",index_col=0)
daf4 = pd.read_csv('../Code#2/CodeLlama/BertScore.csv',sep=",",index_col=0)
daf5 = pd.read_csv('../Code#2/Platypus2/BertScore.csv',sep=",",index_col=0)
daf6 = pd.read_csv('../Code#2/StableCode/BertScore.csv',sep=",",index_col=0)

# %%
for i in range(1,7):
    exec(f'print(df{i}.iloc[-1])')
# Out:
# p     0.749840
# f     0.802419
# f1    0.773912
# f3    0.796321
# Name: average, dtype: float64
# p     0.743066
# f     0.794201
# f1    0.766087
# f3    0.788144
# Name: average, dtype: float64
# p     0.741483
# f     0.808213
# f1    0.772165
# f3    0.800514
# Name: average, dtype: float64
# p     0.777251
# f     0.793003
# f1    0.783742
# f3    0.790933
# Name: average, dtype: float64
# p     0.721556
# f     0.696570
# f1    0.707495
# f3    0.698521
# Name: average, dtype: float64
# p     0.688413
# f     0.673964
# f1    0.680170
# f3    0.675047
# Name: average, dtype: float64

# %%
for i in range(1,7):
    exec(f'print(daf{i}.iloc[-1])')
# Out:
# p     0.861876
# f     0.868266
# f1    0.863926
# f3    0.867213
# Name: average, dtype: float64
# p     0.840518
# f     0.873742
# f1    0.854791
# f3    0.869542
# Name: average, dtype: float64
# p     0.804201
# f     0.867441
# f1    0.833173
# f3    0.860106
# Name: average, dtype: float64
# p     0.851506
# f     0.863281
# f1    0.856310
# f3    0.861712
# Name: average, dtype: float64
# p     0.818785
# f     0.835395
# f1    0.826287
# f3    0.833438
# Name: average, dtype: float64
# p     0.755690
# f     0.797815
# f1    0.775072
# f3    0.792970
# Name: average, dtype: float64

# %%
# print(df1.loc['average'])
# print(daf1.loc['average'])
# print((df1.loc['average']+daf1.loc['average'])/2)
for i in range(1,7):
    exec(f'print((df{i}.iloc[-1]+daf{i}.iloc[-1])/2)')
# Out:
# p     0.805858
# f     0.835342
# f1    0.818919
# f3    0.831767
# Name: average, dtype: float64
# p     0.791792
# f     0.833971
# f1    0.810439
# f3    0.828843
# Name: average, dtype: float64
# p     0.772842
# f     0.837827
# f1    0.802669
# f3    0.830310
# Name: average, dtype: float64
# p     0.814379
# f     0.828142
# f1    0.820026
# f3    0.826322
# Name: average, dtype: float64
# p     0.770170
# f     0.765982
# f1    0.766891
# f3    0.765979
# Name: average, dtype: float64
# p     0.722051
# f     0.735890
# f1    0.727621
# f3    0.734009
# Name: average, dtype: float64

# %%
df1 = pd.read_csv('../Code#1/Bard/BertScore.csv',sep=",",index_col=0)
df2 = pd.read_csv('../Code#1/ChatGPT_3.5/BertScore.csv',sep=",",index_col=0)
df3 = pd.read_csv('../Code#1/ChatGPT_4/BertScore.csv',sep=",",index_col=0)
df4 = pd.read_csv('../Code#1/CodeLlama/BertScore.csv',sep=",",index_col=0)
df5 = pd.read_csv('../Code#1/Platypus2/BertScore.csv',sep=",",index_col=0)
df6 = pd.read_csv('../Code#1/StableCode/BertScore.csv',sep=",",index_col=0)

daf1 = pd.read_csv('../Code#2/Bard/BertScore.csv',sep=",",index_col=0)
daf2 = pd.read_csv('../Code#2/ChatGPT_3.5/BertScore.csv',sep=",",index_col=0)
daf3 = pd.read_csv('../Code#2/ChatGPT_4/BertScore.csv',sep=",",index_col=0)
daf4 = pd.read_csv('../Code#2/CodeLlama/BertScore.csv',sep=",",index_col=0)
daf5 = pd.read_csv('../Code#2/Platypus2/BertScore.csv',sep=",",index_col=0)
daf6 = pd.read_csv('../Code#2/StableCode/BertScore.csv',sep=",",index_col=0)
print(df1)
# Out:
#                 p         f        f1        f3
# 0        0.855884  0.948918  0.900003  0.938714
# 1        0.746791  0.826907  0.784809  0.818130
# 2        0.786313  0.704735  0.743292  0.712123
# 3        0.756263  0.787827  0.771722  0.784552
# 4        0.769097  0.828904  0.797881  0.822508
# 5        0.810862  0.830703  0.820662  0.828675
# 6        0.719640  0.795605  0.755718  0.787294
# 7        0.787168  0.729443  0.757207  0.734832
# 8        0.694889  0.836103  0.758983  0.819450
# 9        0.764626  0.788701  0.776477  0.786226
# 10       0.737252  0.821655  0.777169  0.812355
# 11       0.772705  0.793511  0.782970  0.791381
# 12       0.760547  0.786622  0.773365  0.783934
# 13       0.661781  0.757455  0.706393  0.746661
# 14       0.640761  0.791809  0.708322  0.773573
# 15       0.814705  0.853006  0.833416  0.849015
# 16       0.675450  0.796268  0.730900  0.782276
# 17       0.737556  0.783462  0.759816  0.778616
# 18       0.711331  0.821441  0.762431  0.808919
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.scatter(x, df1['f3'],label='Bard')
ax1.scatter(x, df2['f3'],label="ChatGPT_3.5")
ax1.scatter(x, df3['f3'],label="ChatGPT_4")
ax1.scatter(x, df4['f3'],label="CodeLlama")
ax1.scatter(x, df5['f3'],label="Platypus2")
ax1.scatter(x, df6['f3'],label="StableCode")
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)
ax1.set_ylim(0.5, 1)
ax1.set_yticks(np.arange(0.5, 1.05, 0.05))
ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Similarity')
# ax1.xticks(np.arange(0,21,2))

ax2.scatter(x, daf1['f3'],label='Bard')
ax2.scatter(x, daf2['f3'],label="ChatGPT_3.5")
ax2.scatter(x, daf3['f3'],label="ChatGPT_4")
ax2.scatter(x, daf4['f3'],label="CodeLlama")
ax2.scatter(x, daf5['f3'],label="Platypus2")
ax2.scatter(x, daf6['f3'],label="StableCode")
# ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05))
ax2.set_ylim(0.5, 1)
ax2.set_yticks(np.arange(0.5, 1.05, 0.05))
ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Similarity')
# ax2.xticks(np.arange(0,21,2))
# fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=5)
fig.set_figwidth(14.5)
plt.savefig('img/Similarity.Prompts.Circle.pdf', bbox_inches='tight')

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.plot(x, df1['f3'],label='Bard',marker="o")
ax1.plot(x, df2['f3'],label="ChatGPT_3.5",marker="s")
ax1.plot(x, df3['f3'],label="ChatGPT_4",marker="^")
ax1.plot(x, df4['f3'],label="CodeLlama",marker="D")
ax1.plot(x, df5['f3'],label="Platypus2",marker="<",color='k')
ax1.plot(x, df6['f3'],label="StableCode",marker="v",color='m')
# ax1.legend(loc='upper center', bbox_to_anchor=(1.2, 0.1), ncol=1)
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)
ax1.set_ylim(0.5, 1)
ax1.set_yticks(np.arange(0.5, 1.05, 0.05))
ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Similarity')
# ax1.xticks(np.arange(0,21,2))

ax2.plot(x, daf1['f3'],label='Bard',marker="o")
ax2.plot(x, daf2['f3'],label="ChatGPT_3.5",marker="s")
ax2.plot(x, daf3['f3'],label="ChatGPT_4",marker="^")
ax2.plot(x, daf4['f3'],label="CodeLlama",marker="D")
ax2.plot(x, daf5['f3'],label="Platypus2",marker="<",color='k')
ax2.plot(x, daf6['f3'],label="StableCode",marker="v",color='m')
#ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)
ax2.set_ylim(0.5, 1)
ax2.set_yticks(np.arange(0.5, 1.05, 0.05))
ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Similarity')
# ax2.xticks(np.arange(0,21,2))
# fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=5)
fig.set_figheight(10)
fig.set_figwidth(14.5)
plt.savefig('img/lineplot.pdf', bbox_inches='tight')

# %%
fig, (ax1, ax2) = plt.subplots(1,2)



x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.scatter(x, df1['f3'],label='Bard',marker="o")
ax1.scatter(x, df2['f3'],label="ChatGPT_3.5",marker="s")
ax1.scatter(x, df3['f3'],label="ChatGPT_4",marker="^")
ax1.scatter(x, df4['f3'],label="CodeLlama",marker="D")
ax1.scatter(x, df5['f3'],label="Platypus2",marker="<",color='k')
ax1.scatter(x, df6['f3'],label="StableCode",marker="v",color='m')
# ax1.legend(loc='upper center', bbox_to_anchor=(1.2, 0.1), ncol=1)
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)
ax1.set_ylim(0.5, 1)
ax1.set_yticks(np.arange(0.5, 1.05, 0.05))
ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Similarity')
# ax1.xticks(np.arange(0,21,2))

ax2.scatter(x, daf1['f3'],label='Bard',marker="o")
ax2.scatter(x, daf2['f3'],label="ChatGPT_3.5",marker="s")
ax2.scatter(x, daf3['f3'],label="ChatGPT_4",marker="^")
ax2.scatter(x, daf4['f3'],label="CodeLlama",marker="D")
ax2.scatter(x, daf5['f3'],label="Platypus2",marker="<",color='k')
ax2.scatter(x, daf6['f3'],label="StableCode",marker="v",color='m')


ax2.set_ylim(0.5, 1)
ax2.set_yticks(np.arange(0.5, 1.05, 0.05))
ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Similarity')
# ax2.xticks(np.arange(0,21,2))
# fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=5)


fig.set_figwidth(14.5)
plt.savefig('img/Similarity.prompts.2.pdf', bbox_inches='tight')

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.scatter(x, df1['f3'],label='Bard',marker="o")
ax1.scatter(x, df2['f3'],label="ChatGPT_3.5",marker="s")
ax1.scatter(x, df3['f3'],label="ChatGPT_4",marker="^")
ax1.scatter(x, df4['f3'],label="CodeLlama",marker="D")
ax1.scatter(x, df5['f3'],label="Platypus2",marker="<",color='k')
ax1.scatter(x, df6['f3'],label="StableCode",marker="v",color='m')
# ax1.legend(loc='upper center', bbox_to_anchor=(1.2, 0.1), ncol=1)
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)
ax1.set_ylim(0.5, 1)
ax1.set_yticks(np.arange(0.5, 1.05, 0.05))
ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Similarity')

# ax1.xticks(np.arange(0,21,2))

ax2.scatter(x, daf1['f3'],label='Bard',marker="o")
ax2.scatter(x, daf2['f3'],label="ChatGPT_3.5",marker="s")
ax2.scatter(x, daf3['f3'],label="ChatGPT_4",marker="^")
ax2.scatter(x, daf4['f3'],label="CodeLlama",marker="D")
ax2.scatter(x, daf5['f3'],label="Platypus2",marker="<",color='k')
ax2.scatter(x, daf6['f3'],label="StableCode",marker="v",color='m')
# ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)
ax2.set_ylim(0.5, 1)
ax2.set_yticks(np.arange(0.5, 1.05, 0.05))
ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Similarity')
fig.set_figheight(5)
fig.set_figwidth(14)
plt.savefig('img/Similarity.Prompts.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

# df = pd.read_csv('../Code#1/Bard/time.csv',header=None)
# print(df.mean(0))

df1 = pd.read_csv('../Code#1/Bard/time.csv',sep=",",header=None)
df2 = pd.read_csv('../Code#1/ChatGPT_3.5/time.csv',sep=",",header=None)
df3 = pd.read_csv('../Code#1/ChatGPT_4/time.csv',sep=",",header=None)
df4 = pd.read_csv('../Code#1/CodeLlama/time.csv',sep=",",header=None)
df5 = pd.read_csv('../Code#1/Platypus2/time.csv',sep=",",header=None)
df6 = pd.read_csv('../Code#1/StableCode/time.csv',sep=",",header=None)

daf1 = pd.read_csv('../Code#2/Bard/time.csv',sep=",",header=None)
daf2 = pd.read_csv('../Code#2/ChatGPT_3.5/time.csv',sep=",",header=None)
daf3 = pd.read_csv('../Code#2/ChatGPT_4/time.csv',sep=",",header=None)
daf4 = pd.read_csv('../Code#2/CodeLlama/time.csv',sep=",",header=None)
daf5 = pd.read_csv('../Code#2/Platypus2/time.csv',sep=",",header=None)
daf6 = pd.read_csv('../Code#2/StableCode/time.csv',sep=",",header=None)

print(df1.mean(1)[21])
print(df2.mean(1)[21])
print(df3.mean(1)[21])
print(df4.mean(1)[21])
print(df5.mean(1)[21])
print(df6.mean(1)[21])
print('--------------')
print(daf1.mean(1)[21])
print(daf2.mean(1)[21])
print(daf3.mean(1)[21])
print(daf4.mean(1)[21])
print(daf5.mean(1)[21])
print(daf6.mean(1)[21])
# Out:
# 10.196507936507937
# 14.213968253968254
# 42.5831746031746
# 47.29742014597332
# 63.522396791548964
# 17.94064990679423
# --------------
# 7.513333333333333
# 9.08968253968254
# 35.64984126984127
# 66.99453682748099
# 122.48292695529877
# 39.05494800068083

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.scatter(x, df1.mean(1),label='Bard',marker="o")
ax1.scatter(x, df2.mean(1),label="ChatGPT_3.5",marker="s")
ax1.scatter(x, df3.mean(1),label="ChatGPT_4",marker="^")
ax1.scatter(x, df4.mean(1),label="CodeLlama",marker="D")
ax1.scatter(x, df5.mean(1),label="Platypus2",marker="<",color='k')
ax1.scatter(x, df6.mean(1),label="StableCode",marker="v",color='m')
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)

# ax1.legend(loc='upper center', bbox_to_anchor=(1.2, 0.1), ncol=1)
ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Time in seconds')
# ax1.xticks(np.arange(0,21,2))

ax2.scatter(x, daf1.mean(1),label='Bard',marker="o")
ax2.scatter(x, daf2.mean(1),label="ChatGPT_3.5",marker="s")
ax2.scatter(x, daf3.mean(1),label="ChatGPT_4",marker="^")
ax2.scatter(x, daf4.mean(1),label="CodeLlama",marker="D")
ax2.scatter(x, daf5.mean(1),label="Platypus2",marker="<",color='k')
ax2.scatter(x, daf6.mean(1),label="StableCode",marker="v",color='m')

ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Time in seconds')
# ax2.xticks(np.arange(0,21,2))
# fig.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=5)

fig.set_figwidth(14.5)
plt.savefig('img/Prompts.time.2.pdf', bbox_inches='tight')

# %%
fig, (ax1, ax2) = plt.subplots(1,2)

x = np.array([f'{i}' for i in range(1,22)] + ['Avg.'])
ax1.scatter(x, df1.mean(1),label='Bard',marker="o")
ax1.scatter(x, df2.mean(1),label="ChatGPT_3.5",marker="s")
ax1.scatter(x, df3.mean(1),label="ChatGPT_4",marker="^")
ax1.scatter(x, df4.mean(1),label="CodeLlama",marker="D")
ax1.scatter(x, df5.mean(1),label="Platypus2",marker="<",color='k')
ax1.scatter(x, df6.mean(1),label="StableCode",marker="v",color='m')
# ax1.legend(loc='upper center', bbox_to_anchor=(1.2, 0.1), ncol=1)
ax1.legend(loc='upper center', bbox_to_anchor=(1.1, -0.1), ncol=6)

ax1.grid(True)
ax1.set_xlabel('Prompts')
ax1.set_ylabel('Time in seconds')
# ax1.xticks(np.arange(0,21,2))

ax2.scatter(x, daf1.mean(1),label='Bard',marker="o")
ax2.scatter(x, daf2.mean(1),label="ChatGPT_3.5",marker="s")
ax2.scatter(x, daf3.mean(1),label="ChatGPT_4",marker="^")
ax2.scatter(x, daf4.mean(1),label="CodeLlama",marker="D")
ax2.scatter(x, daf5.mean(1),label="Platypus2",marker="<",color='k')
ax2.scatter(x, daf6.mean(1),label="StableCode",marker="v",color='m')

ax2.grid(True)
ax2.set_xlabel('Prompts')
ax2.set_ylabel('Time in seconds')
fig.set_figheight(5)
fig.set_figwidth(14)
plt.savefig('img/Prompts.time.pdf', bbox_inches='tight')
